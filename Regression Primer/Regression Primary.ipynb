# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv("C:/Users/ewojnow/Documents/DataScience/kc_house_data.csv")
# %matplotlib inline
plt.rcParams["figure.figsize"] = [12,9]
print(data.columns)
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
plt.scatter(data.price.head(200),data.yr_built.head(200))
plt.set_xlabel('xlabel')
plt.set_ylabel('ylabel')
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-a5bdf678bf32> in <module>()
#       1 plt.scatter(data.price.head(200),data.yr_built.head(200))
# ----> 2 plt.set_xlabel('xlabel')
#       3 plt.set_ylabel('ylabel')
#       4 plt.grid()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'set_xlabel'
